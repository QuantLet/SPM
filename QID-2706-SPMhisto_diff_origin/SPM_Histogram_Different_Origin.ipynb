# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to read stock data from a file
def read_stock_data(filename):
    with open(filename, 'r') as file:
        data = np.loadtxt(file)
    return data

# Read the stock data from the 'stockres.dat' file
filename = 'stockres.dat'
stock_data = read_stock_data(filename)

# Define bin width and starting points
bin_width = 0.04
starting_points = [0, 0.02, 0.01, 0.03]

# Create subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Plot histograms with the same bin width and different starting points
for ax, x0 in zip(axs.ravel(), starting_points):
    bins = np.arange(min(stock_data), max(stock_data) + bin_width, bin_width) + x0
    ax.hist(stock_data, bins=bins, edgecolor='black', color='white')
    ax.set_title(f'h={bin_width}, x0={x0}')
    
    # Customize the appearance of the plot
    ax.grid(False)
    ax.set_axisbelow(True)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_linewidth(0.5)
    ax.spines['bottom'].set_linewidth(0.5)

# Adjust layout
plt.tight_layout()
plt.show()

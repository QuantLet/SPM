# %%
# Re-plot and extend the range further to ensure smooth continuity on the left side as well
t_extended = np.linspace(-9, 9, 400)

# Recalculate the logistic functions over the extended range
F_t_extended = expit(t_extended)
F_t_plus_alpha_extended = expit(t_extended - 3)

plt.figure(figsize=(8, 6))

# Plot the extended logistic functions
plt.plot(t_extended, F_t_extended, label=r"$F(t)$", color='black')
plt.plot(t_extended, F_t_plus_alpha_extended, label=r"$F(t+\alpha)$", color='black')

# Add labels and title
plt.title("Horizontal Distance", fontsize=16)
plt.xlabel("Index Values t", fontsize=14)
plt.ylabel(r"Link Functions $F(t), F(t+\alpha)$", fontsize=14)

# Add beta annotation with arrow in the same position
plt.annotate(r"$\beta$", xy=(3, 0.5), xytext=(0, 0.5),
             arrowprops=dict(arrowstyle='<->', lw=1.5), fontsize=16)

# Adjust the x-axis limits to show smooth continuity on the left side
plt.xlim(-9, 9)
plt.ylim(0, 1)

# Add ticks and grid to match the original style
plt.xticks(np.arange(-9, 10, 3))
plt.yticks(np.arange(0, 1.1, 0.2))

# Remove the background grid
plt.grid(False)

# Show plot
plt.show()
